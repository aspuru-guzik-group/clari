# %%
# !pip install clari py3dmol

# %%
from clari.inference import ClariSampler
from clari.inference.sample import sample_trajectory
from clari.chem.draw import draw_crystal_trajectory_from_batch

sampler = ClariSampler("clari-h")

out = sample_trajectory(
    sampler,
    ["CC(=O)Oc1ccccc1C(=O)O", "O"],
    copies=[1, 3],
    id="aspirin_trihydrate",
    n_samples=1,
)

# %%
view = draw_crystal_trajectory_from_batch(out, batch_idx=0)
view.show()
# Out:
# <div id="3dmolviewer_17806848953862953"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17806848953862953" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
# ...
